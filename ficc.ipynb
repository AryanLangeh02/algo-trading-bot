# %% [markdown]
# # Basic Fixed Income Trading Bot
# Basic fixed income trading bot that trades TLT: iShares 20+ Year Treasury Bond ETF, MUB: iShares National Muni Bond ETF, LQD: iShares iBoxx $ Investment Grade Corporate Bond ETF, MBB: iShares MBS ETF with a moving average strategy, with 20% drawdown

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: appdirs==1.4.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: appnope==0.1.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (0.1.3)
# Requirement already satisfied: asttokens==2.2.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: backcall==0.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: backtrader==1.9.78.123 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (1.9.78.123)
# Requirement already satisfied: beautifulsoup4==4.12.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: bokeh==3.2.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (3.2.2)
# Requirement already satisfied: btplotting==0.2.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.2.1)
# Requirement already satisfied: certifi==2023.7.22 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (2023.7.22)
# Requirement already satisfied: charset-normalizer==3.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (3.2.0)
# Requirement already satisfied: comm==0.1.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (0.1.4)
# Requirement already satisfied: contourpy==1.1.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: cycler==0.11.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (0.11.0)
# Requirement already satisfied: debugpy==1.6.7.post1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (1.6.7.post1)
# Requirement already satisfied: decorator==5.1.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (5.1.1)
# Requirement already satisfied: executing==1.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (1.2.0)
# Requirement already satisfied: fonttools==4.42.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (4.42.1)
# Requirement already satisfied: frozendict==2.3.8 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (2.3.8)
# Requirement already satisfied: html5lib==1.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (1.1)
# Requirement already satisfied: idna==3.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (3.4)
# Requirement already satisfied: importlib-metadata==6.8.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (6.8.0)
# Requirement already satisfied: importlib-resources==6.0.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (6.0.1)
# Requirement already satisfied: ipykernel==6.25.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (6.25.1)
# Requirement already satisfied: ipython==8.14.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (8.14.0)
# Requirement already satisfied: jedi==0.19.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.19.0)
# Requirement already satisfied: Jinja2==3.1.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (3.1.2)
# Requirement already satisfied: joblib==1.3.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (1.3.2)
# Requirement already satisfied: jupyter-client==8.3.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (8.3.0)
# Requirement already satisfied: jupyter-core==5.3.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (5.3.1)
# Requirement already satisfied: kiwisolver==1.4.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (1.4.4)
# Requirement already satisfied: lxml==4.9.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (4.9.3)
# Requirement already satisfied: MarkupSafe==2.1.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (2.1.3)
# Requirement already satisfied: matplotlib==3.7.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (3.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (0.1.6)
# Requirement already satisfied: multitasking==0.0.11 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.0.11)
# Requirement already satisfied: nest-asyncio==1.5.7 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (1.5.7)
# Requirement already satisfied: numpy==1.25.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (1.25.2)
# Requirement already satisfied: packaging==23.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (23.1)
# Requirement already satisfied: pandas==2.0.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (2.0.3)
# Requirement already satisfied: pandas-datareader==0.10.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (0.10.0)
# Requirement already satisfied: parso==0.8.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.8.3)
# Requirement already satisfied: pexpect==4.8.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (0.7.5)
# Requirement already satisfied: Pillow==10.0.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (10.0.0)
# Requirement already satisfied: platformdirs==3.10.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (3.10.0)
# Requirement already satisfied: prompt-toolkit==3.0.39 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 46)) (3.0.39)
# Requirement already satisfied: psutil==5.9.5 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 47)) (5.9.5)
# Requirement already satisfied: ptyprocess==0.7.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 48)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 49)) (0.2.2)
# Requirement already satisfied: Pygments==2.16.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 50)) (2.16.1)
# Requirement already satisfied: pyparsing==3.0.9 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 51)) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 52)) (2.8.2)
# Requirement already satisfied: pytz==2023.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 53)) (2023.3)
# Requirement already satisfied: PyYAML==6.0.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 54)) (6.0.1)
# Requirement already satisfied: pyzmq==25.1.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 55)) (25.1.1)
# Requirement already satisfied: requests==2.31.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 56)) (2.31.0)
# Requirement already satisfied: scikit-learn==1.3.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 57)) (1.3.0)
# Requirement already satisfied: scipy==1.11.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 58)) (1.11.2)
# Requirement already satisfied: six==1.16.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 59)) (1.16.0)
# Requirement already satisfied: soupsieve==2.4.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 60)) (2.4.1)
# Requirement already satisfied: stack-data==0.6.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 61)) (0.6.2)
# Requirement already satisfied: threadpoolctl==3.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 62)) (3.2.0)
# Requirement already satisfied: tornado==6.3.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 63)) (6.3.3)
# Requirement already satisfied: traitlets==5.9.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 64)) (5.9.0)
# Requirement already satisfied: typing-extensions==4.7.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 65)) (4.7.1)
# Requirement already satisfied: tzdata==2023.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 66)) (2023.3)
# Requirement already satisfied: urllib3==2.0.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 67)) (2.0.4)
# Requirement already satisfied: wcwidth==0.2.6 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 68)) (0.2.6)
# Requirement already satisfied: webencodings==0.5.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 69)) (0.5.1)
# Requirement already satisfied: xyzservices==2023.7.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 70)) (2023.7.0)
# Requirement already satisfied: yfinance==0.2.28 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 71)) (0.2.28)
# Requirement already satisfied: zipp==3.16.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 72)) (3.16.2)
# WARNING: You are using pip version 20.2.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/Users/aryanlangeh/algo-trading-bot/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np

# %%
# Fetch data function
def fetch_data(ticker):
    asset = yf.Ticker(ticker)
    data = asset.history(period="1y")['Close']
    return data

# %%
# Fetch data
tickers = ['IEF', 'MBB', 'LQD']  # ETFs representing different fixed income classes
prices = {ticker: fetch_data(ticker) for ticker in tickers}

# %%
initial_balance = 100000  # Initial investment in USD
balance = initial_balance
portfolio = {ticker: 0 for ticker in tickers}
cash = initial_balance
trade_count = 0
winning_trades = 0

# %%
df = yf.download(tickers, start='2023-08-01', end='2023-08-28')
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
# Strategy parameters
sma_short = 20
sma_long = 50
bollinger_window = 20
bollinger_num_std_dev = 2
macd_short = 12
macd_long = 26
macd_signal = 9

# %%
# Create DataFrame to hold signals
signals = {}

for ticker in tickers:
    signals[ticker] = pd.DataFrame(index=df.index)
    signals[ticker]['price'] = df['Adj Close'][ticker]
    print("Calculating signals for " + ticker)
    
    # Moving Averages
    signals[ticker]['sma_short'] = signals[ticker]['price'].rolling(window=sma_short).mean()
    signals[ticker]['sma_long'] = signals[ticker]['price'].rolling(window=sma_long).mean()
    print(signals[ticker]['sma_short'])
    print(signals[ticker]['sma_long'])

    # Bollinger Bands
    signals[ticker]['rolling_mean'] = signals[ticker]['price'].rolling(window=bollinger_window).mean()
    signals[ticker]['rolling_std'] = signals[ticker]['price'].rolling(window=bollinger_window).std()
    signals[ticker]['bollinger_upper'] = signals[ticker]['rolling_mean'] + (signals[ticker]['rolling_std'] * bollinger_num_std_dev)
    signals[ticker]['bollinger_lower'] = signals[ticker]['rolling_mean'] - (signals[ticker]['rolling_std'] * bollinger_num_std_dev)
    print(signals[ticker]['bollinger_upper'])
    print(signals[ticker]['bollinger_lower'])

    # MACD
    signals[ticker]['ema_short'] = signals[ticker]['price'].ewm(span=macd_short, adjust=False).mean()
    signals[ticker]['ema_long'] = signals[ticker]['price'].ewm(span=macd_long, adjust=False).mean()
    signals[ticker]['macd'] = signals[ticker]['ema_short'] - signals[ticker]['ema_long']
    signals[ticker]['signal_line'] = signals[ticker]['macd'].ewm(span=macd_signal, adjust=False).mean()
    print(signals[ticker]['macd'])
    print(signals[ticker]['signal_line'])

    # Create Buy and Sell signals
    signals[ticker]['positions'] = 0.0
    
    # Buy if price > sma_long and price > bollinger_lower and macd > signal_line
    buy_mask = (signals[ticker]['price'] > signals[ticker]['sma_long']) & \
               (signals[ticker]['price'] > signals[ticker]['bollinger_lower']) & \
               (signals[ticker]['macd'] > signals[ticker]['signal_line'])

    signals[ticker].loc[buy_mask, 'positions'] = 1.0
    
    # Sell if price < sma_long or price < bollinger_upper or macd < signal_line
    sell_mask = (signals[ticker]['price'] < signals[ticker]['sma_long']) | \
                (signals[ticker]['price'] < signals[ticker]['bollinger_upper']) | \
                (signals[ticker]['macd'] < signals[ticker]['signal_line'])
    
    signals[ticker].loc[sell_mask, 'positions'] = -1.0
# Out:
# Calculating signals for IEF
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: sma_short, dtype: float64
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: sma_long, dtype: float64
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: bollinger_upper, dtype: float64
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: bollinger_lower, dtype: float64
# Date
# 2023-08-01    0.000000
# 2023-08-02   -0.015157
# 2023-08-03   -0.082699
# 2023-08-04   -0.054903
# 2023-08-07   -0.050847
# 2023-08-08   -0.008799
# 2023-08-09    0.029031
# 2023-08-10    0.000105
# 2023-08-11   -0.062445
# 2023-08-14   -0.122705
# 2023-08-15   -0.182878
# 2023-08-16   -0.256656
# 2023-08-17   -0.321107
# 2023-08-18   -0.345608
# 2023-08-21   -0.407133
# 2023-08-22   -0.447506
# 2023-08-23   -0.393467
# 2023-08-24   -0.374565
# 2023-08-25   -0.357880
# Name: macd, dtype: float64
# Date
# 2023-08-01    0.000000
# 2023-08-02   -0.003031
# 2023-08-03   -0.018965
# 2023-08-04   -0.026153
# 2023-08-07   -0.031091
# 2023-08-08   -0.026633
# 2023-08-09   -0.015500
# 2023-08-10   -0.012379
# 2023-08-11   -0.022392
# 2023-08-14   -0.042455
# 2023-08-15   -0.070540
# 2023-08-16   -0.107763
# 2023-08-17   -0.150432
# 2023-08-18   -0.189467
# 2023-08-21   -0.233000
# 2023-08-22   -0.275901
# 2023-08-23   -0.299414
# 2023-08-24   -0.314445
# 2023-08-25   -0.323132
# Name: signal_line, dtype: float64
# Calculating signals for MBB
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: sma_short, dtype: float64
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: sma_long, dtype: float64
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: bollinger_upper, dtype: float64
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: bollinger_lower, dtype: float64
# Date
# 2023-08-01    0.000000
# 2023-08-02   -0.031909
# 2023-08-03   -0.113183
# 2023-08-04   -0.108562
# 2023-08-07   -0.106097
# 2023-08-08   -0.076631
# 2023-08-09   -0.035921
# 2023-08-10   -0.055467
# 2023-08-11   -0.106047
# 2023-08-14   -0.155634
# 2023-08-15   -0.215845
# 2023-08-16   -0.280502
# 2023-08-17   -0.324772
# 2023-08-18   -0.342992
# 2023-08-21   -0.397232
# 2023-08-22   -0.432010
# 2023-08-23   -0.372170
# 2023-08-24   -0.348168
# 2023-08-25   -0.319811
# Name: macd, dtype: float64
# Date
# 2023-08-01    0.000000
# 2023-08-02   -0.006382
# 2023-08-03   -0.027742
# 2023-08-04   -0.043906
# 2023-08-07   -0.056344
# 2023-08-08   -0.060402
# 2023-08-09   -0.055505
# 2023-08-10   -0.055498
# 2023-08-11   -0.065608
# 2023-08-14   -0.083613
# 2023-08-15   -0.110059
# 2023-08-16   -0.144148
# 2023-08-17   -0.180273
# 2023-08-18   -0.212817
# 2023-08-21   -0.249700
# 2023-08-22   -0.286162
# 2023-08-23   -0.303363
# 2023-08-24   -0.312324
# 2023-08-25   -0.313822
# Name: signal_line, dtype: float64
# Calculating signals for LQD
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: sma_short, dtype: float64
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: sma_long, dtype: float64
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: bollinger_upper, dtype: float64
# Date
# 2023-08-01   NaN
# 2023-08-02   NaN
# 2023-08-03   NaN
# 2023-08-04   NaN
# 2023-08-07   NaN
# 2023-08-08   NaN
# 2023-08-09   NaN
# 2023-08-10   NaN
# 2023-08-11   NaN
# 2023-08-14   NaN
# 2023-08-15   NaN
# 2023-08-16   NaN
# 2023-08-17   NaN
# 2023-08-18   NaN
# 2023-08-21   NaN
# 2023-08-22   NaN
# 2023-08-23   NaN
# 2023-08-24   NaN
# 2023-08-25   NaN
# Name: bollinger_lower, dtype: float64
# Date
# 2023-08-01    0.000000
# 2023-08-02   -0.051852
# 2023-08-03   -0.167670
# 2023-08-04   -0.169547
# 2023-08-07   -0.189827
# 2023-08-08   -0.170049
# 2023-08-09   -0.144637
# 2023-08-10   -0.182908
# 2023-08-11   -0.239527
# 2023-08-14   -0.284347
# 2023-08-15   -0.360097
# 2023-08-16   -0.452835
# 2023-08-17   -0.542668
# 2023-08-18   -0.575755
# 2023-08-21   -0.644575
# 2023-08-22   -0.665621
# 2023-08-23   -0.558057
# 2023-08-24   -0.496142
# 2023-08-25   -0.437193
# Name: macd, dtype: float64
# Date
# 2023-08-01    0.000000
# 2023-08-02   -0.010370
# 2023-08-03   -0.041830
# 2023-08-04   -0.067374
# 2023-08-07   -0.091864
# 2023-08-08   -0.107501
# 2023-08-09   -0.114928
# 2023-08-10   -0.128524
# 2023-08-11   -0.150725
# 2023-08-14   -0.177449
# 2023-08-15   -0.213979
# 2023-08-16   -0.261750
# 2023-08-17   -0.317934
# 2023-08-18   -0.369498
# 2023-08-21   -0.424513
# 2023-08-22   -0.472735
# 2023-08-23   -0.489799
# 2023-08-24   -0.491068
# 2023-08-25   -0.480293
# Name: signal_line, dtype: float64

# %%
# Initialize additional variables
max_drawdown = 0.2  # 20% maximum allowable drawdown
fee_per_trade = 5  # $5 fee per trade

# Risk management variables
highest_balance = initial_balance  # Record of the highest account balance
drawdown_limit = highest_balance * max_drawdown  # Calculate the maximum allowable drawdown

# %%
# Backtesting
for i in range(1, len(df)):
    current_balance = cash
    for ticker in portfolio:
        current_balance += portfolio[ticker] * df['Adj Close'][ticker].iloc[i]

    # Update highest_balance if current_balance is higher
    highest_balance = max(highest_balance, current_balance)
    drawdown_limit = highest_balance * max_drawdown  # Update the maximum allowable drawdown
    
    if current_balance >= drawdown_limit:  # Only trade if the current balance is above drawdown limit
        for ticker in tickers:
            # Buy signal
            if signals[ticker]['positions'].iloc[i] == 1.0:
                if cash >= (signals[ticker]['price'].iloc[i] + fee_per_trade):
                    cash -= (signals[ticker]['price'].iloc[i] + fee_per_trade)
                    portfolio[ticker] += 1
                    trade_count += 1

            # Sell signal
            elif signals[ticker]['positions'].iloc[i] == -1.0:
                if portfolio[ticker] > 0:
                    cash += (signals[ticker]['price'].iloc[i] - fee_per_trade)
                    portfolio[ticker] -= 1
                    trade_count += 1
                    if cash > initial_balance:
                        winning_trades += 1

# %%
# Final account balance
final_balance = cash
for ticker in portfolio:
    final_balance += portfolio[ticker] * df['Adj Close'][ticker].iloc[i]

print(f"Final balance: ${final_balance:.2f}")
print(f"Trade Count: {trade_count}")
print(f"Winning Trades: {winning_trades}")
print(f"Winning Rate: {winning_trades / trade_count * 100 if trade_count > 0 else 0:.2f}%")
# Out:
# Final balance: $97043.06
# Trade Count: 576
# Winning Trades: 0
# Winning Rate: 0.00%
